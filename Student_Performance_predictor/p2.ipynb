# %% [markdown]
# # Load Data

# %%
import pandas as pd
df = pd.read_csv('student_data.csv')
print(df.head())
# Out:
#    Hours  Marks
# 0      5     15
# 1      2     18
# 2     20     25
# 3     12     32
# 4      5     45

# %% [markdown]
# # visualize

# %%
import matplotlib.pyplot as plt
plt.scatter(df['Hours'], df['Marks'])
plt.xlabel('Hours Studied')
plt.ylabel('Exam Score')
plt.title('Hours Studied vs Exam Score with Real Data')
plt.show()

# %% [markdown]
# # Train-Test Split

# %%
from sklearn.model_selection import train_test_split
x = df[['Hours']]
y = df['Marks']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %% [markdown]
# # Train Model

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # Accuracy Check

# %%
from sklearn.metrics import r2_score
y_pred = model.predict(x_test)
print("R-squared Score//Accuracy:", r2_score(y_test, y_pred))
# Out:
# R-squared Score//Accuracy: -0.402311697732606

# %% [markdown]
# # Prediction Test

# %%
import numpy as np
hours = np.array([[7]])

prediction = model.predict(hours)
print(f"Predicted score for studying {hours[0][0]} hours: {prediction[0]:.2f}")
# Out:
# Predicted score for studying 7 hours: 49.13
# c:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
